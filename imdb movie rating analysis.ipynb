# %%
import pandas as pd

# %%
ratings = pd.read_csv(r'C:\Users\mikim\OneDrive\Desktop\DATA SCIENCE\kaggle\archive (1)\rating.csv')

# %%
ratings.shape #dimention of table ratings
# Out:
# (20000263, 4)

# %%
ratings.head(1) #gives only 1 row
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47

# %%
tags = pd.read_csv(r'C:\Users\mikim\OneDrive\Desktop\DATA SCIENCE\kaggle\archive (1)\tag.csv')

# %%
tags.shape #dimention of table tags
# Out:
# (465564, 4)

# %%
tags.head(5) #gives only first 5 rows
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
movies = pd.read_csv(r'C:\Users\mikim\OneDrive\Desktop\DATA SCIENCE\kaggle\archive (1)\movie.csv')

# %%
movies.shape #dimention of table movies
# Out:
# (27278, 3)

# %%
type(movies) #type of table movies
# Out:
# pandas.core.frame.DataFrame

# %%
movies.head(20) #gives first 20 rows
# Out:
#     movieId                                  title  \
# 0         1                       Toy Story (1995)
# 1         2                         Jumanji (1995)
# 2         3                Grumpier Old Men (1995)
# 3         4               Waiting to Exhale (1995)
# 4         5     Father of the Bride Part II (1995)
# 5         6                            Heat (1995)
# 6         7                         Sabrina (1995)
# 7         8                    Tom and Huck (1995)
# 8         9                    Sudden Death (1995)
# 9        10                       GoldenEye (1995)
# 10       11         American President, The (1995)
# 11       12     Dracula: Dead and Loving It (1995)
# 12       13                           Balto (1995)
# 13       14                           Nixon (1995)
# 14       15                Cutthroat Island (1995)
# 15       16                          Casino (1995)
# 16       17           Sense and Sensibility (1995)
# ...

# %%
#delete a column
del ratings['timestamp']
del tags['timestamp']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[374], line 3
#       1 #delete a column
#       2 del ratings['timestamp']
# ...

# %%
ratings.shape #dimention of table ratings

# %% [markdown]
# Data Structure

# %%
# Series
row_0 = tags.iloc[0]
type(row_0)

# %%
print(row_0)

# %%
row_0.index

# %%
row_0['userId']

# %%
'rating' in row_0

# %%
row_0.name

# %%
row_0 = row_0.rename('firstRow')
row_0.name

# %% [markdown]
# Data Frames

# %%
tags.head()

# %%
tags.index

# %%
tags.columns

# %%
tags.iloc[[0,11,500]]

# %% [markdown]
# Descriptive Statistics

# %%
ratings['rating'].describe()

# %%
ratings.describe() #gives statistical analysis of table ratings

# %%
ratings['rating'].mean() #gives the mean of column rating in ratings table

# %%
ratings.mean()

# %%
ratings['rating'].min() #gives minimum of column rating in ratings table

# %%
ratings['rating'].max() #gives maximum of column rating in ratings table

# %%
ratings['rating'].std() #gives standard deviation of column rating in ratings table

# %%
ratings['rating'].mode() #gives mode of column rating in ratings table

# %%
ratings.corr()

# %%
filter1 = ratings['rating'] > 10
print(filter1)
filter1.any()

# %%
filter2 = ratings['rating'] >0
filter2.all()

# %% [markdown]
# Data Cleaning: Handling Missing Data

# %%
movies.shape

# %%
movies.isnull().any().any()

# %%
ratings.shape

# %%
ratings.isnull().any().any()

# %%
tags.shape

# %%
tags.isnull().any().any()

# %%
tags = tags.dropna()

# %%
tags.isnull().any().any()

# %%
tags.shape

# %% [markdown]
# Data Visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

ratings.hist(column='rating', figsize=(10,5))
plt.show()

# %%
ratings.boxplot(column= 'rating', figsize=(10,5))
plt.show()

# %% [markdown]
# 📤 Slicing Out Columns

# %%
tags['tag'].head()

# %%
movies[['title','genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tag_counts = tags['tag'].value_counts()
tag_counts[-10:]
# Out:
# tag
# missing child                    1
# Ron Moore                        1
# Citizen Kane                     1
# mullet                           1
# biker gang                       1
# Paul Adelstein                   1
# the wig                          1
# killer fish                      1
# genetically modified monsters    1
# topless scene                    1
# Name: count, dtype: int64

# %%
colors = plt.cm.Paired.colors
tag_counts[:10].plot(kind='bar', figsize=(10,5), color=colors)
plt.show()

# %% [markdown]
# Filters for Selecting Rows

# %%
is_highly_rated = ratings['rating'] >=5.0
ratings[is_highly_rated][30:50]
# Out:
#      userId  movieId  rating
# 239       3       50     5.0
# 242       3      175     5.0
# 244       3      223     5.0
# 245       3      260     5.0
# 246       3      316     5.0
# 247       3      318     5.0
# 248       3      329     5.0
# 252       3      457     5.0
# 253       3      480     5.0
# 254       3      490     5.0
# 256       3      541     5.0
# 258       3      593     5.0
# 263       3      858     5.0
# 264       3      904     5.0
# 267       3      924     5.0
# 268       3      953     5.0
# 271       3     1060     5.0
# 272       3     1073     5.0
# 275       3     1084     5.0
# 276       3     1089     5.0

# %%
is_action = movies['genres'].str.contains('Action')
movies[is_action][5:15]
# Out:
#     movieId                                      title  \
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                            genres
# 22          Action|Crime|Thriller
# 41             Action|Crime|Drama
# 43       Action|Adventure|Fantasy
# 50          Action|Drama|Thriller
# 65         Action|Sci-Fi|Thriller
# 69  Action|Comedy|Horror|Thriller
# 70                         Action
# 75         Action|Sci-Fi|Thriller
# 77    Action|Crime|Drama|Thriller
# ...

# %%
movies[is_action].head(15)
# Out:
#     movieId                                      title  \
# 5         6                                Heat (1995)
# 8         9                        Sudden Death (1995)
# 9        10                           GoldenEye (1995)
# 14       15                    Cutthroat Island (1995)
# 19       20                         Money Train (1995)
# 22       23                           Assassins (1995)
# 41       42                     Dead Presidents (1995)
# 43       44                       Mortal Kombat (1995)
# 50       51                      Guardian Angel (1994)
# 65       66  Lawnmower Man 2: Beyond Cyberspace (1996)
# 69       70                 From Dusk Till Dawn (1996)
# 70       71                           Fair Game (1995)
# 75       76                           Screamers (1995)
# 77       78                 Crossing Guard, The (1995)
# 85       86                        White Squall (1996)
#
#                                 genres
# 5                Action|Crime|Thriller
# ...

# %% [markdown]
# Group By and Aggregate

# %%
ratings_count = ratings[['movieId','rating']].groupby('rating').count()
ratings_count
# Out:
#         movieId
# rating
# 0.5      239125
# 1.0      680732
# 1.5      279252
# 2.0     1430997
# 2.5      883398
# 3.0     4291193
# 3.5     2200156
# 4.0     5561926
# 4.5     1534824
# 5.0     2898660

# %%
average_rating = ratings[['movieId','rating']].groupby('movieId').mean()
average_rating.head()
# Out:
#            rating
# movieId
# 1        3.921240
# 2        3.211977
# 3        3.151040
# 4        2.861393
# 5        3.064592

# %%
movie_count = ratings[['movieId','rating']].groupby('movieId').count()
movie_count.head()
# Out:
#          rating
# movieId
# 1         49695
# 2         22243
# 3         12735
# 4          2756
# 5         12161

# %%
movie_count = ratings[['movieId','rating']].groupby('movieId').count()
movie_count.tail()
# Out:
#          rating
# movieId
# 131254        1
# 131256        1
# 131258        1
# 131260        1
# 131262        1

# %% [markdown]
# Merge DataFrames

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
t = movies.merge(tags, on='movieId', how='inner')
t.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId                                     tag
# 0    1644                                 Watched
# 1    1741                      computer animation
# 2    1741                 Disney animated feature
# 3    1741                         Pixar animation
# 4    1741  TÃ©a Leoni does not star in this movie

# %% [markdown]
# Combine aggreagation, merging, and filters to get useful analytics

# %%
avg_ratings= ratings.groupby('movieId', as_index=False).mean()
del avg_ratings['userId']
avg_ratings.head()
# Out:
#    movieId    rating
# 0        1  3.921240
# 1        2  3.211977
# 2        3  3.151040
# 3        4  2.861393
# 4        5  3.064592

# %%
box_office = movies.merge(avg_ratings, on='movieId', how='inner')
box_office.tail()
# Out:
#        movieId                          title                    genres  \
# 26739   131254   Kein Bund für's Leben (2007)                    Comedy
# 26740   131256  Feuer, Eis & Dosenbier (2002)                    Comedy
# 26741   131258             The Pirates (2014)                 Adventure
# 26742   131260            Rentun Ruusu (2001)        (no genres listed)
# 26743   131262               Innocence (2014)  Adventure|Fantasy|Horror
#
#        rating
# 26739     4.0
# 26740     4.0
# 26741     2.5
# 26742     3.0
# 26743     4.0

# %%
is_highly_rated = box_office['rating'] >= 4.0
box_office[is_highly_rated][-5:]
# Out:
#        movieId                                              title  \
# 26737   131250                              No More School (2000)
# 26738   131252  Forklift Driver Klaus: The First Day on the Jo...
# 26739   131254                       Kein Bund für's Leben (2007)
# 26740   131256                      Feuer, Eis & Dosenbier (2002)
# 26743   131262                                   Innocence (2014)
#
#                          genres  rating
# 26737                    Comedy     4.0
# 26738             Comedy|Horror     4.0
# 26739                    Comedy     4.0
# 26740                    Comedy     4.0
# 26743  Adventure|Fantasy|Horror     4.0

# %%
is_Adventure = box_office['genres'].str.contains('Adventure')
box_office[is_Adventure][:5]
# Out:
#     movieId                title                                       genres  \
# 0         1     Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1         2       Jumanji (1995)                   Adventure|Children|Fantasy
# 7         8  Tom and Huck (1995)                           Adventure|Children
# 9        10     GoldenEye (1995)                    Action|Adventure|Thriller
# 12       13         Balto (1995)                 Adventure|Animation|Children
#
#       rating
# 0   3.921240
# 1   3.211977
# 7   3.142049
# 9   3.430029
# 12  3.272416

# %%
box_office[is_Adventure & is_highly_rated][-5:]
# Out:
#        movieId                                              title  \
# 26611   130586                Itinerary of a Spoiled Child (1988)
# 26655   130996                         The Beautiful Story (1992)
# 26667   131050  Stargate SG-1 Children of the Gods - Final Cut...
# 26736   131248                              Brother Bear 2 (2006)
# 26743   131262                                   Innocence (2014)
#
#                                             genres  rating
# 26611                              Adventure|Drama     4.5
# 26655                      Adventure|Drama|Fantasy     5.0
# 26667                    Adventure|Sci-Fi|Thriller     5.0
# 26736  Adventure|Animation|Children|Comedy|Fantasy     4.0
# 26743                     Adventure|Fantasy|Horror     4.0

# %% [markdown]
# Vectorized String Operations

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# Split 'genres' into multiple columns

# %%
movie_genres = movies['genres'].str.split('I', expand = True)

# %%
movie_genres[:10]
# Out:
#                                              0     1
# 0  Adventure|Animation|Children|Comedy|Fantasy  None
# 1                   Adventure|Children|Fantasy  None
# 2                               Comedy|Romance  None
# 3                         Comedy|Drama|Romance  None
# 4                                       Comedy  None
# 5                        Action|Crime|Thriller  None
# 6                               Comedy|Romance  None
# 7                           Adventure|Children  None
# 8                                       Action  None
# 9                    Action|Adventure|Thriller  None

# %% [markdown]
# Add a new column for comedy genre flag

# %%
movie_genres['isComedy'] = movies['genres'].str.contains('comedy')
movie_genres[:10]
# Out:
#                                              0     1  isComedy
# 0  Adventure|Animation|Children|Comedy|Fantasy  None     False
# 1                   Adventure|Children|Fantasy  None     False
# 2                               Comedy|Romance  None     False
# 3                         Comedy|Drama|Romance  None     False
# 4                                       Comedy  None     False
# 5                        Action|Crime|Thriller  None     False
# 6                               Comedy|Romance  None     False
# 7                           Adventure|Children  None     False
# 8                                       Action  None     False
# 9                    Action|Adventure|Thriller  None     False
